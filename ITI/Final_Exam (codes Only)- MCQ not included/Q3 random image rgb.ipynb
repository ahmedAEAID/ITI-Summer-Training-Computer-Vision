# %%
import numpy as np 
import cv2
import matplotlib.pyplot as plt

# %%
img = np.zeros((250,250,3),np.int16)
for row in range(len(img)) :
    img[row,:] = np.random.randint(0,255,(1,3))
plt.imshow(img)
plt.show()
