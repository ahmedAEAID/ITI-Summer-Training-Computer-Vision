# %% [markdown]
# # Exercise Lecture 2

# %%
lis=[1,2,3,4,5,6,7]
flag = False
for i in lis:
    num = lis.count(i)
    if num >1:
        flag = True
        break;
print(flag)
# Out:
# False

# %%
lis=[1,2,3,4,5,5,6,7,7]
flag = False
for i in lis:
    num = lis.count(i)
    if num >1:
        flag = True
        break;
print(flag)
# Out:
# True

# %% [markdown]
# ### anther answer

# %%
lis=[1,2,3,4,5,6,7]

if len(lis) == len(set(lis)) :
  print(False)
else:
  print(True)
# Out:
# False

# %%
lis=[1,2,3,4,5,5,6,7,7]
if len(lis) == len(set(lis)) :
  print(False)
else:
  print(True)
# Out:
# True
