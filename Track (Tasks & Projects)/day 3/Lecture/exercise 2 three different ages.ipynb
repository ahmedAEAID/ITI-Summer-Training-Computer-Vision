# %%
age1 =int (input('Enter the first age: '))
age2 =int (input('Enter the second age: '))
age3 =int (input('Enter the third age: '))

the_yongest = min(min(age1,age2),age3)
the_oldest = max(max(age1,age2),age3)
print('the yongest is ' ,the_yongest)
print('the oldest is ',the_oldest)
# Out:
# Enter the first age: 12
# Enter the second age: 17
# Enter the third age: 10
# the yongest is  10
# the oldest is  17

# %%
age1 =int (input('Enter the first age: '))
age2 =int (input('Enter the second age: '))
age3 =int (input('Enter the third age: '))
oldest = 0
if (age1> age2 and age1> age3):
    oldest = age1
    
elif (age2 > age1 and age2> age3):
    oldest = age2
else:
    oldest = age3


youngest = 0
if (age1 < age2 and age1 < age3):
    youngest = age1
    
elif (age2 < age1 and age2 < age3):
    youngest = age2
else:
    youngest = age3

print("The younest is", youngest)
print("The oldest is", oldest)
# Out:
# Enter the first age: 12
# Enter the second age: 19
# Enter the third age: 10
# The younest is 10
# The oldest is 19
